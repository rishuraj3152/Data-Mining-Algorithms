# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from copy import deepcopy

# %%
df=pd.read_excel("Absenteeism_at_work.xls",index_col=0)

# %%
df.head()
# Out:
#     Reason for absence  Month of absence  Day of the week  Seasons  \
# ID
# 11                  26                 7                3        1
# 36                   0                 7                3        1
# 3                   23                 7                4        1
# 7                    7                 7                5        1
# 11                  23                 7                5        1
#
#     Transportation expense  Distance from Residence to Work  Service time  \
# ID
# 11                     289                               36            13
# 36                     118                               13            18
# 3                      179                               51            18
# 7                      279                                5            14
# 11                     289                               36            13
#
#     Age  Work load Average/day   Hit target  Disciplinary failure  Education  \
# ID
# 11   33                  239554          97                     0          1
# 36   50                  239554          97                     1          1
# 3    38                  239554          97                     0          1
# 7    39                  239554          97                     0          1
# 11   33                  239554          97                     0          1
#
#     Son  Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# ID
# 11    2               1              0    1      90     172               30
# 36    1               1              0    0      98     178               31
# 3     0               1              0    0      89     170               31
# 7     2               1              1    0      68     168               24
# 11    2               1              0    1      90     172               30
#
#     Absenteeism time in hours
# ID
# 11                          4
# 36                          0
# 3                           2
# 7                           4
# 11                          2

# %%
data = df.values[:, 0:19]
category = df.values[:,19]

# %%
k = 3
m = data.shape[0]
n = data.shape[1]
mean = np.mean(data, axis = 0)
std = np.std(data, axis = 0)
centers = np.random.randn(k,n)*std + mean
print(centers.shape)
# Out:
# (3, 19)

# %%
centers_old = np.zeros(centers.shape)
centers_new = deepcopy(centers)

data.shape
clusters = np.zeros(m)
distances = np.zeros((m,k))

error = np.linalg.norm(centers_new - centers_old)


while error != 0:
    
    for i in range(k):
        distances[:,i] = np.linalg.norm(data - centers[i], axis=1)
    
    clusters = np.argmin(distances, axis = 1)
    
    centers_old = deepcopy(centers_new)
   
    for i in range(k):
        centers_new[i] = np.mean(data[clusters == i], axis=0)
    error = np.linalg.norm(centers_new - centers_old)
centers_new
# Out:
# array([[1.72282609e+01, 3.84782609e+00, 3.89130435e+00, 2.61956522e+00,
#         2.27641304e+02, 2.91630435e+01, 1.31413043e+01, 3.67608696e+01,
#         3.50184696e+05, 9.51195652e+01, 5.43478261e-02, 1.15217391e+00,
#         1.27173913e+00, 6.52173913e-01, 1.19565217e-01, 7.50000000e-01,
#         7.94673913e+01, 1.73847826e+02, 2.62391304e+01],
#        [1.94673046e+01, 6.63157895e+00, 3.92663477e+00, 2.58532695e+00,
#         2.19138756e+02, 2.93843700e+01, 1.25039872e+01, 3.64178628e+01,
#         2.62139593e+05, 9.45964912e+01, 5.58213716e-02, 1.31738437e+00,
#         9.76076555e-01, 5.50239234e-01, 6.22009569e-02, 7.17703349e-01,
#         7.88309410e+01, 1.71912281e+02, 2.66762360e+01],
#        [2.04285714e+01, 8.00000000e+00, 3.66666667e+00, 1.00000000e+00,
#         2.59095238e+02, 3.90476190e+01, 1.14761905e+01, 3.60476190e+01,
#         2.05917000e+05, 9.20000000e+01, 0.00000000e+00, 1.14285714e+00,
#         1.19047619e+00, 7.14285714e-01, 1.90476190e-01, 1.57142857e+00,
#         8.32380952e+01, 1.70571429e+02, 2.86190476e+01]])
